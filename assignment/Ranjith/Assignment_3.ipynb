# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
pwd
# Out:
# '/content'

# %%
df=pd.read_csv('abalone.csv')

# %%
df.head(10)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7
# 5         0.120      8
# 6         0.330     20
# 7         0.260     16
# 8         0.165      9
# 9         0.320     19

# %%
Age=1.5+df.Rings
df["Age"]=Age
df=df.rename(columns = {'Whole weight':'Whole_weight','Shucked weight': 'Shucked_weight','Viscera weight': 'Viscera_weight',
                            'Shell weight': 'Shell_weight'})
df=df.drop(columns=["Rings"],axis=1)
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole_weight    4177 non-null   float64
#  5   Shucked_weight  4177 non-null   float64
#  6   Viscera_weight  4177 non-null   float64
#  7   Shell_weight    4177 non-null   float64
#  8   Age             4177 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# *Pre Processing*

# %%
df.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole_weight      False
# Shucked_weight    False
# Viscera_weight    False
# Shell_weight      False
# Age               False
# dtype: bool

# %%
df.head(10)
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell_weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5
# 5         0.120   9.5
# 6         0.330  21.5
# 7         0.260  17.5
# 8         0.165  10.5
# 9         0.320  20.5

# %% [markdown]
# **Descriptive statistics**

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_weight  Shell_weight          Age
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831    11.433684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     2.500000
# 25%          0.093500      0.130000     9.500000
# 50%          0.171000      0.234000    10.500000
# 75%          0.253000      0.329000    12.500000
# max          0.760000      1.005000    30.500000

# %%
df.Sex.unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
df.Sex.value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %% [markdown]
# **Visualization**

# %%
sns.displot(df.Length)

# %%
sns.displot(df.Diameter)

# %%
sns.displot(df.Height)

# %%
sns.displot(df.Whole_weight)

# %%
sns.displot(df.Shucked_weight)

# %%
sns.displot(df.Viscera_weight)

# %%
sns.displot(df.Shell_weight)

# %%
sns.displot(df.Sex)

# %%
sns.barplot(df.Sex.value_counts().index,df.Sex.value_counts())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Sex,df.Length)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Sex,df.Length)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Length,df.Diameter)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Length,df.Diameter)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Length,df.Height)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Length,df.Height)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Length,df.Whole_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Length,df.Whole_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Length,df.Shucked_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Length,df.Shucked_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Length,df.Viscera_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Length,df.Viscera_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Length,df.Shell_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Length,df.Shell_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Diameter,df.Shell_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Diameter,df.Shell_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Diameter,df.Whole_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Diameter,df.Whole_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Shell_weight,df.Whole_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Shell_weight,df.Whole_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.Shucked_weight,df.Viscera_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.Shucked_weight,df.Viscera_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6e6f488e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e6f548390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e6f3bc990>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6e6f3f1f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e6f3f9590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e6f42fb90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6e6f5321d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e6f4ea7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6e6f320e10>]],
#       dtype=object)

# %%
sns.pairplot(df)

# %% [markdown]
# **Handling Outliers**

# %%
sns.boxplot(df.Length)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
q1=df.Length.quantile(0.25)  #(Q1)
q3=df.Length.quantile(0.75)  #(Q3)

# %%
IQR=q3-q1

# %%
upper_limit= q3 + 1.5*IQR

lower_limit= q1 - 1.5*IQR

# %%
upper_limit
# Out:
# 0.8624999999999999

# %%
lower_limit
# Out:
# 0.20250000000000004

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length             0.5450
# Diameter           0.4250
# Height             0.1400
# Whole_weight       0.7995
# Shucked_weight     0.3360
# Viscera_weight     0.1710
# Shell_weight       0.2340
# Age               10.5000
# dtype: float64

# %%
df['Length']= np.where(df['Length']<lower_limit,0.5450,df['Length'])

sns.boxplot(df.Length)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.Height)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
q1=df.Height.quantile(0.25)  #(Q1)
q3=df.Height.quantile(0.75)  #(Q3)

IQR=q3-q1

upper_limit= q3 + 1.5*IQR

lower_limit= q1 - 1.5*IQR

# %%
upper_limit
# Out:
# 0.24000000000000002

# %%
lower_limit
# Out:
# 0.039999999999999994

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length             0.5450
# Diameter           0.4250
# Height             0.1400
# Whole_weight       0.7995
# Shucked_weight     0.3360
# Viscera_weight     0.1710
# Shell_weight       0.2340
# Age               10.5000
# dtype: float64

# %%
df['Height']= np.where(df['Height']<lower_limit,0.1400,df['Height'])

df['Height']= np.where(df['Height']>upper_limit,0.1400,df['Height'])

# %%
sns.boxplot(df.Height)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.Diameter)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
q1=df.Diameter.quantile(0.25)  #(Q1)
q3=df.Diameter.quantile(0.75)  #(Q3)

IQR=q3-q1

upper_limit= q3 + 1.5*IQR

lower_limit= q1 - 1.5*IQR

# %%
upper_limit
# Out:
# 0.675

# %%
lower_limit
# Out:
# 0.15499999999999997

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length             0.5450
# Diameter           0.4250
# Height             0.1400
# Whole_weight       0.7995
# Shucked_weight     0.3360
# Viscera_weight     0.1710
# Shell_weight       0.2340
# Age               10.5000
# dtype: float64

# %%
df['Diameter']= np.where(df['Diameter']<lower_limit, 0.4250,df['Diameter'])
sns.boxplot(df.Diameter)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.Whole_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
q1=df.Whole_weight.quantile(0.25)  #(Q1)
q3=df.Whole_weight.quantile(0.75)  #(Q3)

IQR=q3-q1

upper_limit= q3 + 1.5*IQR

lower_limit= q1 - 1.5*IQR

# %%
upper_limit
# Out:
# 2.22025

# %%
lower_limit
# Out:
# -0.62575

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length             0.5450
# Diameter           0.4250
# Height             0.1400
# Whole_weight       0.7995
# Shucked_weight     0.3360
# Viscera_weight     0.1710
# Shell_weight       0.2340
# Age               10.5000
# dtype: float64

# %%
df['Whole_weight']= np.where(df['Whole_weight']>upper_limit,0.7995,df['Whole_weight'])
sns.boxplot(df.Whole_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.Shucked_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
q1=df.Shucked_weight.quantile(0.25)  #(Q1)
q3=df.Shucked_weight.quantile(0.75)  #(Q3)

IQR=q3-q1

upper_limit= q3 + 1.5*IQR

lower_limit= q1 - 1.5*IQR

# %%
upper_limit
# Out:
# 0.976

# %%
lower_limit
# Out:
# -0.288

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length             0.5450
# Diameter           0.4250
# Height             0.1400
# Whole_weight       0.7995
# Shucked_weight     0.3360
# Viscera_weight     0.1710
# Shell_weight       0.2340
# Age               10.5000
# dtype: float64

# %%
df['Shucked_weight']= np.where(df['Shucked_weight']>upper_limit,0.3360,df['Shucked_weight'])
sns.boxplot(df.Shucked_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.Viscera_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
q1=df.Viscera_weight.quantile(0.25)  #(Q1)
q3=df.Viscera_weight.quantile(0.75)  #(Q3)
IQR=q3-q1
upper_limit= q3 + 1.5*IQR

lower_limit= q1 - 1.5*IQR

# %%
upper_limit
# Out:
# 0.49225

# %%
lower_limit
# Out:
# -0.14575000000000002

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length             0.5450
# Diameter           0.4250
# Height             0.1400
# Whole_weight       0.7995
# Shucked_weight     0.3360
# Viscera_weight     0.1710
# Shell_weight       0.2340
# Age               10.5000
# dtype: float64

# %%
df['Viscera_weight']= np.where(df['Viscera_weight']>upper_limit,0.1710,df['Viscera_weight'])
sns.boxplot(df.Viscera_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.Shell_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
q1=df.Shell_weight.quantile(0.25)  #(Q1)
q3=df.Shell_weight.quantile(0.75)  #(Q3)
IQR=q3-q1
upper_limit= q3 + 1.5*IQR

lower_limit= q1 - 1.5*IQR

# %%
upper_limit
# Out:
# 0.6275

# %%
lower_limit
# Out:
# -0.16849999999999998

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length             0.5450
# Diameter           0.4250
# Height             0.1400
# Whole_weight       0.7995
# Shucked_weight     0.3360
# Viscera_weight     0.1710
# Shell_weight       0.2340
# Age               10.5000
# dtype: float64

# %%
df['Shell_weight']= np.where(df['Shell_weight']>upper_limit,0.2340,df['Shell_weight'])
sns.boxplot(df.Shell_weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Label Encoder**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.Sex=le.fit_transform(df.Sex)
df.head(10)
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
# 5    1   0.425     0.300   0.095        0.3515          0.1410
# 6    0   0.530     0.415   0.150        0.7775          0.2370
# 7    0   0.545     0.425   0.125        0.7680          0.2940
# 8    2   0.475     0.370   0.125        0.5095          0.2165
# 9    0   0.550     0.440   0.150        0.8945          0.3145
#
#    Viscera_weight  Shell_weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# 4          0.0395         0.055   8.5
# 5          0.0775         0.120   9.5
# 6          0.1415         0.330  21.5
# 7          0.1495         0.260  17.5
# 8          0.1125         0.165  10.5
# 9          0.1510         0.320  20.5

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole_weight  \
# Sex             1.000000 -0.032999 -0.035934 -0.041976     -0.028695
# Length         -0.032999  1.000000  0.973234  0.871633      0.903973
# Diameter       -0.035934  0.973234  1.000000  0.871498      0.898864
# Height         -0.041976  0.871633  0.871498  1.000000      0.874416
# Whole_weight   -0.028695  0.903973  0.898864  0.874416      1.000000
# Shucked_weight -0.020533  0.878470  0.869731  0.821263      0.939880
# Viscera_weight -0.037293  0.883640  0.876330  0.856081      0.944322
# Shell_weight   -0.039365  0.885617  0.888250  0.880501      0.928024
# Age            -0.034627  0.516360  0.528001  0.594727      0.540937
#
#                 Shucked_weight  Viscera_weight  Shell_weight       Age
# Sex                  -0.020533       -0.037293     -0.039365 -0.034627
# Length                0.878470        0.883640      0.885617  0.516360
# Diameter              0.869731        0.876330      0.888250  0.528001
# Height                0.821263        0.856081      0.880501  0.594727
# Whole_weight          0.939880        0.944322      0.928024  0.540937
# Shucked_weight        1.000000        0.901219      0.857370  0.431656
# Viscera_weight        0.901219        1.000000      0.887565  0.507776
# Shell_weight          0.857370        0.887565      1.000000  0.606431
# Age                   0.431656        0.507776      0.606431  1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)

# %%
df.corr().Age.sort_values(ascending=False)
# Out:
# Age               1.000000
# Shell_weight      0.606431
# Height            0.594727
# Whole_weight      0.540937
# Diameter          0.528001
# Length            0.516360
# Viscera_weight    0.507776
# Shucked_weight    0.431656
# Sex              -0.034627
# Name: Age, dtype: float64

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# 4          0.0395         0.055   8.5

# %% [markdown]
# **X and Y split**

# %%
y=df['Age']
y
# Out:
# 0       16.5
# 1        8.5
# 2       10.5
# 3       11.5
# 4        8.5
#         ...
# 4172    12.5
# 4173    11.5
# 4174    10.5
# 4175    11.5
# 4176    13.5
# Name: Age, Length: 4177, dtype: float64

# %%
X=df.drop(columns=['Age'],axis=1)
X.head(10)
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
# 5    1   0.425     0.300   0.095        0.3515          0.1410
# 6    0   0.530     0.415   0.150        0.7775          0.2370
# 7    0   0.545     0.425   0.125        0.7680          0.2940
# 8    2   0.475     0.370   0.125        0.5095          0.2165
# 9    0   0.550     0.440   0.150        0.8945          0.3145
#
#    Viscera_weight  Shell_weight
# 0          0.1010         0.150
# 1          0.0485         0.070
# 2          0.1415         0.210
# 3          0.1140         0.155
# 4          0.0395         0.055
# 5          0.0775         0.120
# 6          0.1415         0.330
# 7          0.1495         0.260
# 8          0.1125         0.165
# 9          0.1510         0.320

# %% [markdown]
# **Scaling**

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
X_scaled=pd.DataFrame(scale.fit_transform(X),columns=X.columns)
X_scaled.head()
# Out:
#    Sex    Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0  1.0  0.409836  0.424242   0.275      0.231884        0.231726
# 1  1.0  0.237705  0.222222   0.250      0.101223        0.102125
# 2  0.0  0.532787  0.535354   0.475      0.305707        0.264904
# 3  1.0  0.385246  0.424242   0.425      0.232790        0.222395
# 4  0.5  0.204918  0.202020   0.200      0.091938        0.091757
#
#    Viscera_weight  Shell_weight
# 0        0.204476      0.238172
# 1        0.097660      0.109864
# 2        0.286877      0.334403
# 3        0.230926      0.246191
# 4        0.079349      0.085806

# %% [markdown]
# **Train Test Split**

# %%
df.shape
# Out:
# (4177, 9)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(X_scaled,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (3341, 8)

# %%
x_test.shape
# Out:
# (836, 8)

# %%
y_train.shape
# Out:
# (3341,)

# %%
y_test.shape
# Out:
# (836,)

# %% [markdown]
# **Model Building**

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test= lr.predict(x_test)
pred_test
# Out:
# array([13.80690384, 10.7601818 , 11.91266938,  7.74165577, 12.64640354,
#        13.01902298,  9.31216917, 10.97864764, 10.20923554, 12.92069473,
#        10.11949968,  8.40216639,  9.76181207, 10.38620015,  8.03417237,
#        11.29885471,  9.24151631, 14.98455396, 13.10311588,  9.41490054,
#         9.18125593,  8.45179656, 10.34075915,  9.24384733, 11.43509847,
#        12.55855133,  9.91319508, 14.42316086, 11.71223636, 12.1205011 ,
#         9.40211493,  9.87172948, 12.89129341, 16.67599634,  9.17428836,
#        10.49697682, 10.60909575, 11.98691159, 10.2029085 , 13.05440209,
#        13.12759813, 10.70654102, 12.77615623, 12.85314185, 13.51936135,
#        10.66760564, 10.98133112, 13.47861294, 13.63000606,  9.50624155,
#        12.47377656,  8.98233344, 10.17762269, 14.60384594, 10.77116619,
#         9.17927021,  8.08496582,  8.90574462,  8.91635132,  8.74968419,
#        11.18490639, 10.79917287, 11.56382915,  9.74223427,  9.56411464,
#        13.93180286, 14.23135486, 14.11588799, 10.73885887, 15.78733251,
#        11.06119929, 13.45082024, 12.96777666, 10.82164   , 11.27119693,
#        10.50679686, 10.77294403, 11.08845824, 12.95452825,  9.53698564,
#        11.24610998,  8.0236658 ,  9.37632552, 14.17192396, 11.70386473,
#         9.66941609, 11.53008288, 14.41166642,  7.29702657,  9.05482723,
#        12.48128381, 10.88624923, 10.07083376, 14.63280029, 13.70605337,
#         7.72024394, 10.06701108,  7.98535683, 11.910391  ,  8.60086397,
#        10.76242463, 12.58436056,  9.88367787,  9.07223948,  9.67178584,
#        14.10936339,  9.70796269, 10.54402351,  8.82494373, 14.50254639,
#         7.98866612, 10.61436011, 10.00776286, 13.29210894, 12.664191  ,
#        10.2997158 , 13.05785422, 13.13366715, 15.04683146, 10.3495999 ,
#        12.38172337,  9.38575916, 10.79829515, 11.08251837,  7.94925884,
#        12.48736843, 10.19456286,  8.8078886 ,  8.60359297, 11.9064996 ,
#         9.20761856, 11.16639574, 10.43183667, 10.38397608, 10.3748597 ,
#        11.19891928, 10.85230099,  9.1454066 , 13.12340888,  9.82675963,
#        13.30778245, 10.75303462,  8.90762907, 11.18199183, 14.8943254 ,
#         8.76650039,  8.66428926,  9.48595897,  8.35120105, 12.60879735,
#        10.93131652, 12.8849545 ,  9.528814  , 12.42491159,  9.74299385,
#         8.73239324, 10.26942414, 14.28209957, 12.32766542, 10.99516202,
#        11.54819422,  8.88148679, 14.04812957,  9.24204119, 11.52602602,
#        15.45881133, 13.5933563 ,  9.39830553,  9.17277312, 10.64380782,
#        10.02983786, 10.65409077, 10.03051955, 11.24966073, 12.24087974,
#        11.17525466, 12.38834829, 14.88745837, 12.82941044, 14.29063651,
#        10.93694762, 12.41670872, 11.32762928,  9.88414708, 11.80553981,
#        10.555068  ,  9.75317226, 10.22474193,  8.03273089,  8.58945058,
#        10.04207917, 10.27323867, 13.21285435,  9.67517926,  9.85097167,
#        10.54531914,  9.26823783, 11.95684554, 13.50715682, 13.43460435,
#        10.51565927, 10.69504665, 12.77862904, 13.07501091, 12.07936668,
#         7.88865785, 11.39550851, 12.94121775,  8.3377301 ,  9.70349407,
#        10.78733012, 12.50376581, 11.56266984,  8.49986829,  8.88677056,
#        10.46530989, 11.95438247, 10.37050597,  9.70218398, 13.87978636,
#         7.76118504])

# %%
y_test
# Out:
# 668     14.5
# 1580     9.5
# 3784    12.5
# 463      6.5
# 2615    13.5
#         ...
# 575     12.5
# 3231    13.5
# 1084     8.5
# 290     18.5
# 2713     5.5
# Name: Age, Length: 836, dtype: float64

# %%
pred_train = lr.predict(x_train)
pred_train
# Out:
# array([ 8.15639516,  9.40335451, 14.41784548, ..., 11.01140138,
#        12.7207057 ,  9.87826696])

# %%
Rings=pd.DataFrame({'Actual_y_value':y_test,'Predicted_y_value':pred_test})
Rings.head(10)
# Out:
#       Actual_y_value  Predicted_y_value
# 668             14.5          13.806904
# 1580             9.5          10.760182
# 3784            12.5          11.912669
# 463              6.5           7.741656
# 2615            13.5          12.646404
# 1399            12.5          13.019023
# 2054             8.5           9.312169
# 2058             9.5          10.978648
# 217              8.5          10.209236
# 1931            10.5          12.920695

# %%
import sklearn.metrics as sm
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, pred_test), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, pred_test), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, pred_test), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, pred_test), 2)) 
print("R2 score =", round(sm.r2_score(y_test, pred_test), 2))
# Out:
# Mean absolute error = 1.7
# Mean squared error = 5.69
# Median absolute error = 1.23
# Explain variance score = 0.48
# R2 score = 0.48
